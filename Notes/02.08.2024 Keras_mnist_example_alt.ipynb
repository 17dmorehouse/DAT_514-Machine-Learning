# %% [markdown]
# This is the MNIST digit problem, but using the Tensor Flow system instead of the scikit-learn version
#
# Tensorflow is the package from Google for machine learning,  the most common pro level tool for ML
#
# The other prominent package for machine learning is called pytorch, we may look at that package later in the semester.  Tensorflow is more common for applications,  pytorch is more of an R&D
# tool

# %%
from tensorflow.keras.datasets import mnist

[train_images,train_labels],[test_images,test_labels]=mnist.load_data(path="D:\\Example_data\\MNIST\mnist.npz")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Note the different storage format, as 28 by 28 images,  not flat arrays this time

# %% [markdown]
# # Building an ML model using the Keras sequential model
# we define the model,  called network here,  with the line models.Sequential()
#
# and then we add layers to it,   specifying the numbers of neuron in the layer, the activation function and the size of the input data in the first layer
#
# in the output layer, we are using a softmax activation,  so the outputs scale from 0 to 1, and sum to one
#
# Notice how much control we have on the model using the keras API in tensorflow to construct the model

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

network=models.Sequential()
network.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
network.add(layers.Dense(10,activation='softmax'))

# %% [markdown]
# Below is a deeper alternative model,   don't run this cell the first time through the notebook,   come back to this book when
# you reach the end and run it from here to see a more complex model in action

# %%
# alternative model- don't run this the first time!   This model adds another layer,  reducing the size of the first layer

network=models.Sequential()
network.add(layers.Dense(128,activation='relu',input_shape=(28*28,)))
network.add(layers.Dense(8,activation='relu'))
network.add(layers.Dense(10,activation='softmax'))

# %% [markdown]
# This is the set of instructions on how we want to see the model fitted.   The loss function and optimizer are specified here
# and we can also indicate that we want performance metrics calculated as this model is trained

# %%
network.compile(optimizer='rmsprop',
               loss='categorical_crossentropy',
               metrics=['accuracy','AUC'])

# %% [markdown]
# We are using a keras utility to convert the test labels to onehot encodings

# %%
from tensorflow.keras.utils import to_categorical

test_labels=to_categorical(test_labels)
train_labels=to_categorical(train_labels)

# %%
test_labels.shape
# Out:
# (10000, 10)

# %% [markdown]
# We are going to reshape the images to the flat form,and also rescale them to the range 0 to 1,  and also convert them to 32 bit float to save a bit of space

# %%
train_images=train_images.reshape(60000,28*28)
train_images=train_images.astype('float32')/255

# %% [markdown]
# We will now split the training set into a test set 2 and a validation set.   We will fit the model using the second training set and use the validation set to test
# the models during the model adjustment process

# %%
from sklearn.model_selection import train_test_split

X_train2, X_valid, y_train2, y_valid = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

# %%
print(X_train2.shape)
print(X_valid.shape)
print(y_train2.shape)
print(y_valid.shape)
# Out:
# (48000, 784)
# (12000, 784)
# (48000, 10)
# (12000, 10)

# %%
print(train_images.shape)
# Out:
# (60000, 784)

# %% [markdown]
# # Model fitting
#
# here is the model fitting process, running for 30 epochs, with a batch size of 512 points
#
# The validation set will be used at the end of each epoch, and the metrics reported
#
# The metrics will all be stored in history

# %%
history=network.fit(X_train2,y_train2,epochs=30,batch_size=512, validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/30
# 94/94 [==============================] - 5s 34ms/step - loss: 1.1448 - accuracy: 0.6460 - auc: 0.9295 - val_loss: 0.6864 - val_accuracy: 0.8142 - val_auc: 0.9734
# Epoch 2/30
# 94/94 [==============================] - 2s 20ms/step - loss: 0.4428 - accuracy: 0.8894 - auc: 0.9873 - val_loss: 0.3321 - val_accuracy: 0.9127 - val_auc: 0.9914
# Epoch 3/30
# 94/94 [==============================] - 1s 13ms/step - loss: 0.2933 - accuracy: 0.9206 - auc: 0.9928 - val_loss: 0.2770 - val_accuracy: 0.9253 - val_auc: 0.9934
# Epoch 4/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2361 - accuracy: 0.9348 - auc: 0.9950 - val_loss: 0.2252 - val_accuracy: 0.9376 - val_auc: 0.9949
# Epoch 5/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.2044 - accuracy: 0.9429 - auc: 0.9960 - val_loss: 0.1982 - val_accuracy: 0.9452 - val_auc: 0.9960
# Epoch 6/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1783 - accuracy: 0.9506 - auc: 0.9967 - val_loss: 0.1902 - val_accuracy: 0.9468 - val_auc: 0.9960
# Epoch 7/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1597 - accuracy: 0.9552 - auc: 0.9972 - val_loss: 0.1697 - val_accuracy: 0.9522 - val_auc: 0.9967
# Epoch 8/30
# 94/94 [==============================] - 1s 10ms/step - loss: 0.1442 - accuracy: 0.9603 - auc: 0.9975 - val_loss: 0.1649 - val_accuracy: 0.9516 - val_auc: 0.9965
# Epoch 9/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1320 - accuracy: 0.9626 - auc: 0.9979 - val_loss: 0.1482 - val_accuracy: 0.9574 - val_auc: 0.9970
# Epoch 10/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1211 - accuracy: 0.9663 - auc: 0.9981 - val_loss: 0.1401 - val_accuracy: 0.9607 - val_auc: 0.9972
# Epoch 11/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1097 - accuracy: 0.9685 - auc: 0.9985 - val_loss: 0.1353 - val_accuracy: 0.9628 - val_auc: 0.9974
# Epoch 12/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1019 - accuracy: 0.9715 - auc: 0.9986 - val_loss: 0.1287 - val_accuracy: 0.9642 - val_auc: 0.9976
# Epoch 13/30
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0947 - accuracy: 0.9741 - auc: 0.9987 - val_loss: 0.1306 - val_accuracy: 0.9618 - val_auc: 0.9974
# Epoch 14/30
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0866 - accuracy: 0.9762 - auc: 0.9989 - val_loss: 0.1216 - val_accuracy: 0.9657 - val_auc: 0.9978
# Epoch 15/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0803 - accuracy: 0.9775 - auc: 0.9991 - val_loss: 0.1309 - val_accuracy: 0.9615 - val_auc: 0.9973
# Epoch 16/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0740 - accuracy: 0.9797 - auc: 0.9992 - val_loss: 0.1179 - val_accuracy: 0.9668 - val_auc: 0.9976
# Epoch 17/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0690 - accuracy: 0.9807 - auc: 0.9993 - val_loss: 0.1193 - val_accuracy: 0.9652 - val_auc: 0.9977
# Epoch 18/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0634 - accuracy: 0.9828 - auc: 0.9994 - val_loss: 0.1315 - val_accuracy: 0.9613 - val_auc: 0.9973
# Epoch 19/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0596 - accuracy: 0.9831 - auc: 0.9994 - val_loss: 0.1090 - val_accuracy: 0.9692 - val_auc: 0.9978
# Epoch 20/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0554 - accuracy: 0.9851 - auc: 0.9995 - val_loss: 0.1159 - val_accuracy: 0.9678 - val_auc: 0.9974
# Epoch 21/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0513 - accuracy: 0.9858 - auc: 0.9996 - val_loss: 0.1140 - val_accuracy: 0.9681 - val_auc: 0.9973
# Epoch 22/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0475 - accuracy: 0.9868 - auc: 0.9996 - val_loss: 0.1093 - val_accuracy: 0.9695 - val_auc: 0.9977
# Epoch 23/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0446 - accuracy: 0.9877 - auc: 0.9997 - val_loss: 0.1107 - val_accuracy: 0.9692 - val_auc: 0.9975
# Epoch 24/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0406 - accuracy: 0.9896 - auc: 0.9997 - val_loss: 0.1083 - val_accuracy: 0.9697 - val_auc: 0.9974
# Epoch 25/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0385 - accuracy: 0.9896 - auc: 0.9997 - val_loss: 0.1141 - val_accuracy: 0.9675 - val_auc: 0.9971
# Epoch 26/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0352 - accuracy: 0.9907 - auc: 0.9998 - val_loss: 0.1056 - val_accuracy: 0.9704 - val_auc: 0.9974
# Epoch 27/30
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0330 - accuracy: 0.9912 - auc: 0.9998 - val_loss: 0.1081 - val_accuracy: 0.9696 - val_auc: 0.9972
# Epoch 28/30
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0300 - accuracy: 0.9927 - auc: 0.9998 - val_loss: 0.1091 - val_accuracy: 0.9706 - val_auc: 0.9972
# Epoch 29/30
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0281 - accuracy: 0.9928 - auc: 0.9998 - val_loss: 0.1124 - val_accuracy: 0.9697 - val_auc: 0.9971
# Epoch 30/30
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0255 - accuracy: 0.9939 - auc: 0.9999 - val_loss: 0.1094 - val_accuracy: 0.9703 - val_auc: 0.9973

# %%
test_loss,test_accuracy,test_AUC=network.evaluate(X_train2,y_train2)
print('test acc:',test_accuracy)
# Out:
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0249 - accuracy: 0.9941 - auc: 0.9999
# test acc: 0.9941458106040955

# %%
print('test AUC',test_AUC)
# Out:
# test AUC 0.9999091625213623

# %% [markdown]
# # Question
#
# This is the MNIST digits problem, using a bit more advanced neural net than we did with data set
# earlier.
#
# But what is claimed performance level look like?    How does it compare with your earlier results?   Is this reasonable?

# %% [markdown]
# # Answer:
#
# This shows us that we have a perfect model and that the model adn correctly perdict the outcome 100% of the time. Which is not reasonable.

# %% [markdown]
# # Now some plots using the history
#
# We can look at the loss function for the training data and the loss function for the cross validation level as a function of the number of training epochs run.
#
# Note that this notebook has two different models, watch what changes the second time we run this
# notebook using the more complex model.

# %%
import matplotlib.pyplot as plt
history_dict=history.history
loss_values=history_dict['loss']
val_loss_values=history_dict['val_loss']
epoch=range(1,len(loss_values)+1)

plt.plot(epoch,loss_values,label='Training Loss')
plt.plot(epoch,val_loss_values,label="Validation_Loss")
plt.title("Traing and Validation loss")
plt.xlabel("epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
AUC=history_dict['auc']
val_AUC=history_dict['val_auc']


plt.plot(epoch,AUC,label='Training AUC')
plt.plot(epoch,val_AUC,label="Validation AUC")
plt.title("Traing and Validation AUC")
plt.xlabel("epochs")
plt.ylabel("AUC")
plt.legend()
plt.show()

# %%
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'auc', 'val_loss', 'val_accuracy', 'val_auc'])

# %%
ACC=history_dict['accuracy']
val_ACC=history_dict['val_accuracy']


plt.plot(epoch,ACC,label='Training Accuracy')
plt.plot(epoch,val_AUC,label="Validation Accuracy")
plt.title("Traing and Validation Accuracy")
plt.xlabel("epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
